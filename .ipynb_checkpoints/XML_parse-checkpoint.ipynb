# %% [markdown]
# # XML Parser

# %% [markdown]
# XML Parser for FCE dataset (https://www.ilexir.co.uk/datasets/index.html).

# %%
import pandas as pd
import os

# %%
# returns list of <p></p> objects for a given XML
def get_p_lst(s):
    ps = []
    s_len = len(s)
    for i in range(s_len):
        if s[i:i+3] == "<p>":
            end_i = i
            while s[end_i:end_i+4] != "</p>":
                end_i += 1
            end_i += 4
            ps.append(s[i:end_i])
    return ps

# %%
# returns the incorrect word and the end index of <i></i> object
def get_i(p_str, i):
    p_i = i
    NS_end = False
#     print("get i ", i)
    while p_str[p_i:p_i+3] != "<i>" and p_i != len(p_str):
        if p_str[p_i:p_i+5] == "</NS>":
#             print("</NS>!!")
            NS_end == True
            return "", i
        p_i += 1
    start_i = p_i + 3
    if p_i == len(p_str) or NS_end:
#         print("no i")
        return "", i
    
    p_i = start_i
    while p_str[p_i:p_i+4] != "</i>":
        p_i += 1
    end_i = p_i 
    
    word = p_str[start_i:end_i]
    
    return word, end_i+4

# returns the correct word and the end index of <c></c> object
def get_c(p_str, i):
    
    p_i = i
    NS_end = False
    
    while p_str[p_i:p_i+3] != "<c>" and p_i != len(p_str):
        if p_str[p_i:p_i+5] == "</NS>":
            NS_end == True
            return "", i
        p_i += 1
    start_i = p_i + 3
    if p_i == len(p_str) or NS_end:
#         print("no c")
        return "", i
    
    p_i = start_i
    while p_str[p_i:p_i+4] != "</c>":
        p_i += 1
    end_i = p_i 
    
    word = p_str[start_i:end_i]
    
    return word, end_i+4
    


# count cascaded <NS> objects
def num_NS_inside_NS(p_str):
    p_i = 0
    open_count = 0
    close_count = 0
    tags = 0
    start = 0
    end = 0
    while p_i != len(p_str):
        if p_str[p_i:p_i+4] == "<NS ":
            if open_count != close_count:
                tags += 1
                if tags == 1:
                    start = p_i
                
            open_count += 1
        elif p_str[p_i:p_i+5] == "</NS>":
            close_count -= 1
        p_i += 1
    return tags

# get the start and the end index of <NS> object
def find_NS(p_str,i_c):
    p_i = i_c
    
    count = 0
    
#     print(len(p_str))
    end = 0
    start = 0
    done = False
    
    while not done:
        if p_str[p_i:p_i+4] == "<NS ":
            if count == 0:
                start = p_i
            count += 1
        elif p_str[p_i:p_i+5] == "</NS>":
            if count == 1:
                end = p_i+5
                done = True
            count -= 1
        p_i += 1
    return start, end

# %%
# for a list of <p> objects, return a list of correct sentences and a list of corresponding incorrect sentences
def correct_and_incorrect_lists(ps):
    correct_sntnc = []
    incorrect_sntnc = []

    for i in range(len(ps)):
        correct = ""
        incorrect = ""
        p_tag = ps[i][3:-4]

        i_c = 0
        while i_c != len(p_tag):

            if p_tag[i_c:i_c+10] == '<NS type="':


                start_NS, end_NS = find_NS(p_tag,i_c)

                if num_NS_inside_NS(p_tag[start_NS: end_NS]) != 0:

                    start_subNS, end_subNS = find_NS(p_tag,i_c+1)
                    sliced_p_tag = p_tag[i_c:start_subNS]+p_tag[end_subNS:]

                    incorrect_w, end_i = get_i(sliced_p_tag, 0)

                    correct_w, end_i = get_c(sliced_p_tag, end_i)

                    incorrect += incorrect_w
                    correct += correct_w


                else:    
                    incorrect_w, end_i = get_i(p_tag, i_c)

                    correct_w, end_i = get_c(p_tag, end_i)

                    incorrect += incorrect_w
                    correct += correct_w

                i_c = end_NS
            else:
                correct += p_tag[i_c]
                incorrect += p_tag[i_c]
                i_c += 1


        correct.replace("  ", " ")
        incorrect.replace("  ", " ")
        correct_sntnc.append(correct)
        incorrect_sntnc.append(incorrect)
    
    return correct_sntnc, incorrect_sntnc

# %%
import xml.etree.ElementTree as ET
import os

data_dir = "/Users/sangencre/Downloads/fce-released-dataset/dataset"

def get_all_filepaths(data_dir):
    return [os.path.join(root, fname)
            for (root, dir_names, file_names) in os.walk(data_dir, followlinks=True)
            for fname in file_names
            if (fname.lower().endswith('.xml'))]

import signal

class TimeoutException(Exception):   # Custom exception class
    pass

def timeout_handler(signum, frame):   # Custom signal handler
    raise TimeoutException



def parse_xml(data_dir):
    filepaths = get_all_filepaths(data_dir)
    d = {"correct": [], "incorrect": []}
#     filepaths =['/Users/sangencre/Downloads/fce-released-dataset/dataset/0102_2000_6/doc838.xml']

    # Change the behavior of SIGALRM
    signal.signal(signal.SIGALRM, timeout_handler)


        
    for path in filepaths:
        signal.alarm(15)
        try:
#             print("parsing", path)
            tree = ET.parse(path)
            root = tree.getroot()
            xmlstr = ET.tostring(root, encoding='utf8', method='xml').decode("utf-8")

            p_list = get_p_lst(xmlstr)

            c_lst, i_lst = correct_and_incorrect_lists(p_list)

            d["correct"] += c_lst
            d["incorrect"] += i_lst
        except TimeoutException:
            continue # continue the for loop if function A takes more than 5 second
        else:
            # Reset the alarm
            signal.alarm(0)
            
    return d
        
parsed_d = parse_xml(data_dir)

# %%
delete_ind = []
d_i = 0
dq = '""'
while d_i != len(parsed_d['correct']):
    if parsed_d['correct'][d_i] == parsed_d['incorrect'][d_i]:
        del parsed_d['correct'][d_i]
        del parsed_d['incorrect'][d_i]
    elif "<NS" in parsed_d['correct'][d_i] or "<NS" in parsed_d['incorrect'][d_i]:
        del parsed_d['correct'][d_i]
        del parsed_d['incorrect'][d_i]
    elif dq in parsed_d['correct'][d_i] or dq in parsed_d['incorrect'][d_i]:
        del parsed_d['correct'][d_i]
        del parsed_d['incorrect'][d_i]
    else:
        d_i += 1

# %%
import pandas as pd

df = pd.DataFrame(data=parsed_d)

# %%
df.head(26)
# Out:
#                                               correct  \
# 0   I WANT TO THANK YOU FOR PREPARING SUCH A GOOD ...
# 1      I WILL BE WAITING ANXIOUSLY FOR YOUR RESPONSE.
# 2   FAMOUS PEOPLE SUCH AS SINGERS, FILM STARS, ETC...
# 3   THIS SITUATION AFFECTS FAMOUS PEOPLE BECAUSE T...
# 4   THE MOST IMPORTANT THING IS THAT, ALTHOUGH THE...
# 5   IN MY OPINION FAMOUS PEOPLE ARE BEING OBLIGED ...
# 6   I have seen your programme for the trip and I ...
# 7   This show is on the 14th March. It is in the C...
# 8   I think it is a great opportunity because it i...
# 9   There will be lots of differences in our homes...
# 10  It is a good start to go on a sightseeing  bus...
# 11  The idea of going to the science museum is fan...
# 12  On Wednesday after we have visited the Nationa...
# 13  The advertisement that the students saw is for...
# 14                                   Yours sincerely,
# 15  Nowadays the main attraction in the newspapers...
# 16  It is really interesting how people like to kn...
# 17  Sometimes being famous can get stressful, beca...
# 18  Famous people deserve to have freedom to do wh...
# 19  On the whole, being rich and famous doesn't al...
# 20  Thank you for organising a good programme, we ...
# 21  We have seen an advertisement in last Saturday...
# 22  Whenever I recollect it, I feel self-confident...
# 23  One year later, I was working in Kang-nam poli...
# 24  But, I was a policeman. Therefore, I had to do...
# 25  On behalf of the class I would like to thank y...
#
#                                             incorrect
# 0   I WANT TO THAK YOU FOR PREPARING SUCH A GOOD P...
# 1      I WILL BE WRITING ANXIOUSLY FOR YOUR RESPONSE.
# 2   FAMOUS PEOPLE SUCH AS SINGERS, FILM STARS, ETC...
# 3   THIS SITUATION AFFECTS FAMOUS PERSONAL LIVES B...
# 4   THE MOST IMPORTANT THING IS THAT, ALTHOUGH THE...
# 5   IN MY OPINION FAMOUS PEOPLE ARE BEING OBLIGED ...
# 6   I have seen your programme for the trip and I ...
# 7   This show is on the 14th March. It is in the C...
# 8   I think it is a great opportunity because it i...
# 9   There will be lots of differences in our homes...
# 10  It is  good start to go on  sightseeing by bus...
# 11  The idea about going to  science museum is fan...
# 12  On Wednesday after  viseted  national Art Gall...
# 13  The advertisement that  students saw is about ...
# 14                                  Yours faithfully,
# 15  Nowadays the main attroction in the newspapers...
# 16  It is really interesting how people like knowi...
# 17  Sometimes being famous can get stress,  everyw...
# 18  Famous people deserve to have freedom to do wh...
# 19  On the whole, to be rich and famous don't alwa...
# 20  Thank you for organising  good programme,  esp...
# 21  We have seen an advertisement of last Saturday...
# 22  Whenever I recollet it, I feel self-confident....
# 23  One year later, I was working in Kang-nam poli...
# 24  But, I was a police-man. Therefore, I had to d...
# 25  In the name of the class I would like to thank...

# %%
df.to_csv(path_or_buf="./parsed.tsv", sep='\t', header=False, index=False, index_label=None, mode='w')

# %%
data_dir = '/Users/sangencre/Desktop/NYU/spring_18/dl/XML_parser'
def get_all_filepaths(data_dir):
    return [os.path.join(root, fname)
            for (root, dir_names, file_names) in os.walk(data_dir, followlinks=True)
            for fname in file_names
            if (fname.lower().endswith('.txt'))]

filepaths = get_all_filepaths(data_dir)
print(filepaths)
# Out:
# ['/Users/sangencre/Desktop/NYU/spring_18/dl/XML_parser/ref1.txt', '/Users/sangencre/Desktop/NYU/spring_18/dl/XML_parser/ref2.txt', '/Users/sangencre/Desktop/NYU/spring_18/dl/XML_parser/ref3.txt', '/Users/sangencre/Desktop/NYU/spring_18/dl/XML_parser/ref4.txt', '/Users/sangencre/Desktop/NYU/spring_18/dl/XML_parser/src.txt']

# %%
pd.read_csv('/Users/sangencre/Desktop/NYU/spring_18/dl/XML_parser/ref1.txt', sep='###', header=0)
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-29fc8efa646a> in <module>()
# ----> 1 pd.read_csv('/Users/sangencre/Desktop/NYU/spring_18/dl/XML_parser/ref1.txt', sep='###', header=False)
#
# /usr/local/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     653                     skip_blank_lines=skip_blank_lines)
#     654
# --> 655         return _read(filepath_or_buffer, kwds)
#     656
#     657     parser_f.__name__ = name
#
# /usr/local/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     403
#     404     # Create the parser.
# --> 405     parser = TextFileReader(filepath_or_buffer, **kwds)
#     406
#     407     if chunksize or iterator:
#
# /usr/local/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     757         # might mutate self.engine
#     758         self.engine = self._check_file_or_buffer(f, engine)
# --> 759         self.options, self.engine = self._clean_options(options, engine)
#     760
#     761         if 'has_index_names' in kwds:
#
# /usr/local/lib/python3.6/site-packages/pandas/io/parsers.py in _clean_options(self, options, engine)
#     915         keep_default_na = result.pop('keep_default_na')
#     916
# --> 917         _validate_header_arg(options['header'])
#     918
#     919         depr_warning = ''
#
# /usr/local/lib/python3.6/site-packages/pandas/io/common.py in _validate_header_arg(header)
#     140 def _validate_header_arg(header):
#     141     if isinstance(header, bool):
# --> 142         raise TypeError("Passing a bool to header is invalid. "
#     143                         "Use header=None for no header or "
#     144                         "header=int or list-like of ints to specify "
#
# TypeError: Passing a bool to header is invalid. Use header=None for no header or header=int or list-like of ints to specify the row(s) making up the column names

# %%
pd.read_csv('/Users/sangencre/Desktop/NYU/spring_18/dl/XML_parser/src.txt', sep='###')
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
#     So I think we can not live if old people could not find siences and tecnologies and they did not developped .
# 0                                    For not use car .
# 1    Here was no promise of morning except that we ...
# 2    Thus even today sex is considered as the least...
# 3    image you salf you are wark in factory just to...
# 4    They draw the consumers , like me , to purchas...
# 5    I want to talk about nocive or bad products li...
# 6    For example they can play football whenever th...
# 7    It figures Diana Krall wearing a Rolex watch a...
# 8                           There are several reason .
# 9    Also the work of the media , television , maga...
# 10   Since most urban areas are occupied with cars ...
# 11   It is true that consumers preffer to buy a pro...
# 12   4:they have a big chance to prepare for their ...
# 13   One person if do n't have good health that mea...
# 14   Many studies over the last 5 0 years have show...
# 15   Likewise , The theory generating from the conc...
# 16     because they spent time unmeaningful subjects .
# 17   I was very fast , my best time was 5 5 seconds...
# 18   And young people spend time more ther lifestile .
# 19   If in this society who will not to do study th...
# 20   We have to know this problem it 's serious but...
# 21   Students can focus on only a few subjects they...
# 22   But in other waythismakes other way country ne...
# 23   Today , MBA students with a background in engi...
# 24   In the case of young people the best way is st...
# 25   So the school try learning the students a bit ...
# 26              I think they have to get skill on it .
# 27   Specializing in one particular subject does no...
# 28   I will explain my points of views in the follo...
# 29   He thinks differently from other people and he...
# ..                                                 ...
# 723  So lets not lose hope and let the scientists d...
# 724  When I was a senior high school student , I sp...
# 725  for example , there may be eldelery travelers ...
# 726  This is evidence , the company that made some ...
# 727  Many people surrounding you admire you of your...
# 728  First of all , It one area allow to become mor...
# 729  In 2 1th our yong people can learn a lot of ac...
# 730  Many climbers died because the coldness and la...
# 731  The new things bring the brainstorm which othe...
# 732  The government would like to reduce the popula...
# 733        Like disking would stop an advancing fire .
# 734  I would spend as much time as I want , if I li...
# 735  So if you want me to choose right now , I will...
# 736  these days our communication also in very good...
# 737  They sometimes teach poor people who cannot af...
# 738  If you randomly find a hotel , it might be eit...
# 739  But not moving and always keeping to old thing...
# 740  Local communities have the main role of protec...
# 741  if they are urged to understand the concept th...
# 742  How they found their work place or foods , so ...
# 743               His success belongs to his new try .
# 744  But if one who majors in art also learns somet...
# 745  Movies and oher television show provides o lot...
# 746  There is many way for this another examples bo...
# 747  It is because they do not think the new thing ...
# 748  Other tourists would teach you some tips for t...
# 749  The government also should try to reduce the s...
# 750  Alot of memories with enogh time to remember w...
# 751            Sceene of violence can affect on them .
# 752  While the communities in general have reckoned...
#
# [753 rows x 1 columns]
